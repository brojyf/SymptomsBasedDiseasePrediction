# %%
# Patrick

# %% [markdown]
# # 1. Import Library

# %%
import math
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from xgboost import XGBClassifier
from collections import Counter
import torch, gc
import shutil
import joblib

torch.cuda.empty_cache()
gc.collect()
use_gpu = shutil.which("nvidia-smi") is not None
print("Using GPU" if use_gpu else "Using CPU")

RANDOM_SEED = 1024
DATA_PATH = "../dataset.csv"
OUT_MODEL = 'output/xgb_model.json'
OUT_CSV = 'output/confusion_matrix.csv'
OUT_LE = "output/label_encoder.pkl"
# Out:
# Using GPU

# %% [markdown]
# # 2. Data Preprocess

# %%
# Remove Duplicate
df = (
    pd.read_csv(DATA_PATH)
      .drop_duplicates()
      .reset_index(drop=True)
)
len(df)
# Out:
# 189647

# %%
# Features / Label
X = df.drop("diseases", axis=1)
y_raw = df["diseases"].str.strip()
le = LabelEncoder().fit(y_raw)
y = pd.Series(le.transform(y_raw), index=X.index)
y.head()
# Out:
# 0    531
# 1    531
# 2    531
# 3    531
# 4    531
# dtype: int64

# %%
# Find Rare Cases
counts = Counter(y)
common_classes = [cls for cls, cnt in counts.items() if cnt >= 2]
rare_classes   = [cls for cls, cnt in counts.items() if cnt <  2]

mask_common = np.isin(y, common_classes)
mask_rare   = ~mask_common

X_common, y_common = X[mask_common], y[mask_common]
X_rare,   y_rare   = X[mask_rare],   y[mask_rare]

# %%
# Test
X_comm_train_val, X_test, y_comm_train_val, y_test = train_test_split(
    X_common, y_common,
    test_size=0.2,
    stratify=y_common,
    random_state=RANDOM_SEED
)

# %%
# Rare Cases -> Train/Val
X_train_val = np.concatenate([X_comm_train_val, X_rare], axis=0)
y_train_val = np.concatenate([y_comm_train_val, y_rare],   axis=0)

# Random
perm = np.random.RandomState(RANDOM_SEED).permutation(len(y_train_val))
X_train_val = X_train_val[perm]
y_train_val = y_train_val[perm]

# %%
# Val
mask_tv_common = np.isin(y_train_val, common_classes)
X_tv_common    = X_train_val[mask_tv_common]
y_tv_common    = y_train_val[mask_tv_common]

X_train_comm, X_val, y_train_comm, y_val = train_test_split(
    X_tv_common, y_tv_common,
    test_size=0.1,
    stratify=y_tv_common,
    random_state=RANDOM_SEED
)

# %%
# Train
mask_tv_rare = ~mask_tv_common
X_tv_rare    = X_train_val[mask_tv_rare]
y_tv_rare    = y_train_val[mask_tv_rare]

X_train = np.concatenate([X_train_comm, X_tv_rare], axis=0)
y_train = np.concatenate([y_train_comm, y_tv_rare],   axis=0)

print(f"Train: {len(X_train)} | Val: {len(X_val)} | Test: {len(X_test)}")
# Out:
# Train: 136558 | Val: 15168 | Test: 37921

# %% [markdown]
# # 3. Training

# %%
def lr_scheduler(round_idx,
                 base_lr=0.03,
                 min_lr=0.003,
                 warmup_rounds=500,
                 total_rounds=15000):
    if round_idx < warmup_rounds:
        return base_lr * ( round_idx+1 )/ warmup_rounds

    decay_rounds = max(1, total_rounds - warmup_rounds)
    progress  = (round_idx - warmup_rounds) / decay_rounds
    return min_lr + 0.5 * (base_lr - min_lr) * (1 + math.cos(progress * math.pi))

# %%
params = {
    # basics
    "objective": "multi:softprob",
    "num_class": len(le.classes_),
    "eval_metric": ["mlogloss", "merror"],
    "random_state": RANDOM_SEED,

    # Tree
    "tree_method": "hist",
    'grow_policy': 'lossguide',
    "min_child_weight": 5,
    "max_depth": 0,
    "max_leaves": 256,
    "gamma": 1.0,

    # Reg
    'reg_alpha': 2,
    'reg_lambda': 1,

    # Sub
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "colsample_bylevel": 0.8,
    "colsample_bynode": 0.8,
    "sampling_method": "gradient_based",

    # LR
    "learning_rate": lambda i:lr_scheduler(i),
    "n_estimators": 15000,
    "early_stopping_rounds": 100,

    # Others
    "device": "cuda" if use_gpu else "cpu",
    "n_jobs": -1,
    'max_delta_step': 1,
}

clf = XGBClassifier(**params)
clf.fit(X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=True)
# Out:
# [0]	validation_0-mlogloss:6.27906	validation_0-merror:0.98332
# [1]	validation_0-mlogloss:5.91147	validation_0-merror:0.94686
# [2]	validation_0-mlogloss:5.54523	validation_0-merror:0.88898
# [3]	validation_0-mlogloss:5.18421	validation_0-merror:0.82997
# [4]	validation_0-mlogloss:4.83033	validation_0-merror:0.72877
# [5]	validation_0-mlogloss:4.48068	validation_0-merror:0.62803
# [6]	validation_0-mlogloss:4.13957	validation_0-merror:0.53198
# [7]	validation_0-mlogloss:3.80746	validation_0-merror:0.44429
# [8]	validation_0-mlogloss:3.48644	validation_0-merror:0.37652
# [9]	validation_0-mlogloss:3.17640	validation_0-merror:0.33617
# [10]	validation_0-mlogloss:2.87845	validation_0-merror:0.30083
# [11]	validation_0-mlogloss:2.59870	validation_0-merror:0.27848
# [12]	validation_0-mlogloss:2.33616	validation_0-merror:0.25943
# [13]	validation_0-mlogloss:2.09201	validation_0-merror:0.24512
# [14]	validation_0-mlogloss:1.87341	validation_0-merror:0.23800
# [15]	validation_0-mlogloss:1.67788	validation_0-merror:0.22811
# [16]	validation_0-mlogloss:1.50575	validation_0-merror:0.22317
# [17]	validation_0-mlogloss:1.35877	validation_0-merror:0.21512
# [18]	validation_0-mlogloss:1.23885	validation_0-merror:0.20972
# [19]	validation_0-mlogloss:1.14273	validation_0-merror:0.20477
# [20]	validation_0-mlogloss:1.06488	validation_0-merror:0.20154
# [21]	validation_0-mlogloss:1.00047	validation_0-merror:0.20207
# [22]	validation_0-mlogloss:0.94712	validation_0-merror:0.19884
# [23]	validation_0-mlogloss:0.90333	validation_0-merror:0.19805
# [24]	validation_0-mlogloss:0.86512	validation_0-merror:0.19620
# [25]	validation_0-mlogloss:0.83263	validation_0-merror:0.19475
# [26]	validation_0-mlogloss:0.80510	validation_0-merror:0.19403
# [27]	validation_0-mlogloss:0.78084	validation_0-merror:0.19376
# [28]	validation_0-mlogloss:0.75956	validation_0-merror:0.19211
# [29]	validation_0-mlogloss:0.74117	validation_0-merror:0.19258
# [30]	validation_0-mlogloss:0.72494	validation_0-merror:0.19231
# [31]	validation_0-mlogloss:0.71115	validation_0-merror:0.19152
# [32]	validation_0-mlogloss:0.69810	validation_0-merror:0.19179
# [33]	validation_0-mlogloss:0.68690	validation_0-merror:0.18948
# [34]	validation_0-mlogloss:0.67678	validation_0-merror:0.18941
# [35]	validation_0-mlogloss:0.66721	validation_0-merror:0.18888
# [36]	validation_0-mlogloss:0.65876	validation_0-merror:0.18882
# [37]	validation_0-mlogloss:0.65114	validation_0-merror:0.18763
# [38]	validation_0-mlogloss:0.64415	validation_0-merror:0.18862
# [39]	validation_0-mlogloss:0.63758	validation_0-merror:0.18776
# [40]	validation_0-mlogloss:0.63184	validation_0-merror:0.18757
# [41]	validation_0-mlogloss:0.62661	validation_0-merror:0.18750
# [42]	validation_0-mlogloss:0.62163	validation_0-merror:0.18730
# [43]	validation_0-mlogloss:0.61687	validation_0-merror:0.18750
# [44]	validation_0-mlogloss:0.61255	validation_0-merror:0.18697
# [45]	validation_0-mlogloss:0.60870	validation_0-merror:0.18724
# [46]	validation_0-mlogloss:0.60525	validation_0-merror:0.18684
# [47]	validation_0-mlogloss:0.60188	validation_0-merror:0.18743
# [48]	validation_0-mlogloss:0.59902	validation_0-merror:0.18783
# [49]	validation_0-mlogloss:0.59608	validation_0-merror:0.18763
# [50]	validation_0-mlogloss:0.59353	validation_0-merror:0.18724
# [51]	validation_0-mlogloss:0.59122	validation_0-merror:0.18757
# [52]	validation_0-mlogloss:0.58891	validation_0-merror:0.18757
# [53]	validation_0-mlogloss:0.58695	validation_0-merror:0.18664
# [54]	validation_0-mlogloss:0.58516	validation_0-merror:0.18697
# [55]	validation_0-mlogloss:0.58351	validation_0-merror:0.18645
# [56]	validation_0-mlogloss:0.58209	validation_0-merror:0.18671
# [57]	validation_0-mlogloss:0.58065	validation_0-merror:0.18618
# [58]	validation_0-mlogloss:0.57940	validation_0-merror:0.18645
# [59]	validation_0-mlogloss:0.57816	validation_0-merror:0.18638
# [60]	validation_0-mlogloss:0.57696	validation_0-merror:0.18658
# [61]	validation_0-mlogloss:0.57598	validation_0-merror:0.18638
# [62]	validation_0-mlogloss:0.57518	validation_0-merror:0.18645
# [63]	validation_0-mlogloss:0.57438	validation_0-merror:0.18664
# [64]	validation_0-mlogloss:0.57364	validation_0-merror:0.18625
# [65]	validation_0-mlogloss:0.57296	validation_0-merror:0.18658
# [66]	validation_0-mlogloss:0.57229	validation_0-merror:0.18658
# [67]	validation_0-mlogloss:0.57173	validation_0-merror:0.18612
# [68]	validation_0-mlogloss:0.57123	validation_0-merror:0.18592
# [69]	validation_0-mlogloss:0.57071	validation_0-merror:0.18651
# [70]	validation_0-mlogloss:0.57029	validation_0-merror:0.18612
# [71]	validation_0-mlogloss:0.56987	validation_0-merror:0.18605
# [72]	validation_0-mlogloss:0.56943	validation_0-merror:0.18605
# [73]	validation_0-mlogloss:0.56910	validation_0-merror:0.18625
# [74]	validation_0-mlogloss:0.56876	validation_0-merror:0.18592
# [75]	validation_0-mlogloss:0.56845	validation_0-merror:0.18526
# [76]	validation_0-mlogloss:0.56816	validation_0-merror:0.18552
# [77]	validation_0-mlogloss:0.56789	validation_0-merror:0.18526
# [78]	validation_0-mlogloss:0.56775	validation_0-merror:0.18565
# [79]	validation_0-mlogloss:0.56756	validation_0-merror:0.18598
# [80]	validation_0-mlogloss:0.56739	validation_0-merror:0.18618
# [81]	validation_0-mlogloss:0.56723	validation_0-merror:0.18618
# [82]	validation_0-mlogloss:0.56710	validation_0-merror:0.18631
# [83]	validation_0-mlogloss:0.56695	validation_0-merror:0.18612
# [84]	validation_0-mlogloss:0.56681	validation_0-merror:0.18631
# [85]	validation_0-mlogloss:0.56670	validation_0-merror:0.18645
# [86]	validation_0-mlogloss:0.56661	validation_0-merror:0.18664
# [87]	validation_0-mlogloss:0.56651	validation_0-merror:0.18658
# [88]	validation_0-mlogloss:0.56647	validation_0-merror:0.18638
# [89]	validation_0-mlogloss:0.56639	validation_0-merror:0.18638
# [90]	validation_0-mlogloss:0.56633	validation_0-merror:0.18631
# [91]	validation_0-mlogloss:0.56629	validation_0-merror:0.18631
# [92]	validation_0-mlogloss:0.56624	validation_0-merror:0.18631
# [93]	validation_0-mlogloss:0.56619	validation_0-merror:0.18618
# [94]	validation_0-mlogloss:0.56616	validation_0-merror:0.18618
# [95]	validation_0-mlogloss:0.56613	validation_0-merror:0.18625
# [96]	validation_0-mlogloss:0.56607	validation_0-merror:0.18612
# [97]	validation_0-mlogloss:0.56603	validation_0-merror:0.18592
# [98]	validation_0-mlogloss:0.56601	validation_0-merror:0.18592
# [99]	validation_0-mlogloss:0.56598	validation_0-merror:0.18592
# [100]	validation_0-mlogloss:0.56595	validation_0-merror:0.18598
# [101]	validation_0-mlogloss:0.56593	validation_0-merror:0.18598
# [102]	validation_0-mlogloss:0.56592	validation_0-merror:0.18605
# [103]	validation_0-mlogloss:0.56590	validation_0-merror:0.18612
# [104]	validation_0-mlogloss:0.56587	validation_0-merror:0.18612
# [105]	validation_0-mlogloss:0.56583	validation_0-merror:0.18612
# [106]	validation_0-mlogloss:0.56582	validation_0-merror:0.18625
# [107]	validation_0-mlogloss:0.56577	validation_0-merror:0.18618
# [108]	validation_0-mlogloss:0.56576	validation_0-merror:0.18612
# [109]	validation_0-mlogloss:0.56576	validation_0-merror:0.18605
# [110]	validation_0-mlogloss:0.56574	validation_0-merror:0.18612
# [111]	validation_0-mlogloss:0.56571	validation_0-merror:0.18605
# [112]	validation_0-mlogloss:0.56569	validation_0-merror:0.18598
# [113]	validation_0-mlogloss:0.56563	validation_0-merror:0.18592
# [114]	validation_0-mlogloss:0.56562	validation_0-merror:0.18592
# [115]	validation_0-mlogloss:0.56560	validation_0-merror:0.18585
# [116]	validation_0-mlogloss:0.56560	validation_0-merror:0.18592
# [117]	validation_0-mlogloss:0.56558	validation_0-merror:0.18592
# [118]	validation_0-mlogloss:0.56558	validation_0-merror:0.18585
# [119]	validation_0-mlogloss:0.56558	validation_0-merror:0.18585
# [120]	validation_0-mlogloss:0.56557	validation_0-merror:0.18579
# [121]	validation_0-mlogloss:0.56555	validation_0-merror:0.18585
# [122]	validation_0-mlogloss:0.56555	validation_0-merror:0.18579
# [123]	validation_0-mlogloss:0.56553	validation_0-merror:0.18585
# [124]	validation_0-mlogloss:0.56554	validation_0-merror:0.18585
# [125]	validation_0-mlogloss:0.56553	validation_0-merror:0.18585
# [126]	validation_0-mlogloss:0.56551	validation_0-merror:0.18585
# [127]	validation_0-mlogloss:0.56549	validation_0-merror:0.18592
# [128]	validation_0-mlogloss:0.56549	validation_0-merror:0.18585
# [129]	validation_0-mlogloss:0.56549	validation_0-merror:0.18585
# [130]	validation_0-mlogloss:0.56549	validation_0-merror:0.18585
# [131]	validation_0-mlogloss:0.56548	validation_0-merror:0.18592
# [132]	validation_0-mlogloss:0.56547	validation_0-merror:0.18592
# [133]	validation_0-mlogloss:0.56545	validation_0-merror:0.18592
# [134]	validation_0-mlogloss:0.56544	validation_0-merror:0.18585
# [135]	validation_0-mlogloss:0.56544	validation_0-merror:0.18585
# [136]	validation_0-mlogloss:0.56543	validation_0-merror:0.18585
# [137]	validation_0-mlogloss:0.56542	validation_0-merror:0.18592
# [138]	validation_0-mlogloss:0.56540	validation_0-merror:0.18605
# [139]	validation_0-mlogloss:0.56539	validation_0-merror:0.18605
# [140]	validation_0-mlogloss:0.56538	validation_0-merror:0.18605
# [141]	validation_0-mlogloss:0.56538	validation_0-merror:0.18612
# [142]	validation_0-mlogloss:0.56537	validation_0-merror:0.18605
# [143]	validation_0-mlogloss:0.56535	validation_0-merror:0.18585
# [144]	validation_0-mlogloss:0.56535	validation_0-merror:0.18579
# [145]	validation_0-mlogloss:0.56535	validation_0-merror:0.18579
# [146]	validation_0-mlogloss:0.56534	validation_0-merror:0.18585
# [147]	validation_0-mlogloss:0.56533	validation_0-merror:0.18585
# [148]	validation_0-mlogloss:0.56533	validation_0-merror:0.18585
# [149]	validation_0-mlogloss:0.56532	validation_0-merror:0.18585
# [150]	validation_0-mlogloss:0.56528	validation_0-merror:0.18585
# [151]	validation_0-mlogloss:0.56527	validation_0-merror:0.18592
# [152]	validation_0-mlogloss:0.56526	validation_0-merror:0.18585
# [153]	validation_0-mlogloss:0.56526	validation_0-merror:0.18592
# [154]	validation_0-mlogloss:0.56525	validation_0-merror:0.18592
# [155]	validation_0-mlogloss:0.56526	validation_0-merror:0.18592
# [156]	validation_0-mlogloss:0.56526	validation_0-merror:0.18592
# [157]	validation_0-mlogloss:0.56526	validation_0-merror:0.18585
# [158]	validation_0-mlogloss:0.56525	validation_0-merror:0.18585
# [159]	validation_0-mlogloss:0.56525	validation_0-merror:0.18585
# [160]	validation_0-mlogloss:0.56525	validation_0-merror:0.18585
# [161]	validation_0-mlogloss:0.56525	validation_0-merror:0.18585
# [162]	validation_0-mlogloss:0.56525	validation_0-merror:0.18585
# [163]	validation_0-mlogloss:0.56524	validation_0-merror:0.18572
# [164]	validation_0-mlogloss:0.56524	validation_0-merror:0.18579
# [165]	validation_0-mlogloss:0.56524	validation_0-merror:0.18579
# [166]	validation_0-mlogloss:0.56523	validation_0-merror:0.18579
# [167]	validation_0-mlogloss:0.56522	validation_0-merror:0.18579
# [168]	validation_0-mlogloss:0.56522	validation_0-merror:0.18579
# [169]	validation_0-mlogloss:0.56519	validation_0-merror:0.18572
# [170]	validation_0-mlogloss:0.56518	validation_0-merror:0.18585
# [171]	validation_0-mlogloss:0.56517	validation_0-merror:0.18572
# [172]	validation_0-mlogloss:0.56516	validation_0-merror:0.18572
# [173]	validation_0-mlogloss:0.56515	validation_0-merror:0.18572
# [174]	validation_0-mlogloss:0.56514	validation_0-merror:0.18572
# [175]	validation_0-mlogloss:0.56514	validation_0-merror:0.18572
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.8, colsample_bynode=0.8, colsample_bytree=0.8,
#               device='cuda', early_stopping_rounds=100,
#               enable_categorical=False, eval_metric=['mlogloss', 'merror'],
#               feature_types=None, gamma=1.0, grow_policy='lossguide',
#               importance_type=None, interaction_constraints=None,
#               learning_rate=<function <lambda> at 0x770485eb5ca0>, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None, max_delta_step=1,
#               max_depth=0, max_leaves=256, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None,
#               n_estimators=15000, n_jobs=-1, num_class=773,
#               num_parallel_tree=None, ...)

# %%
clf.save_model(OUT_MODEL)
joblib.dump(le, OUT_LE)
# Out:
# ['output/label_encoder.pkl']

# %% [markdown]
# # 4. Evaluation

# %%
test_clf = XGBClassifier()
test_clf.load_model("output/xgb_model.json")
test_clf.set_params(tree_method='hist',
               device='cuda' if use_gpu else 'cpu')

y_pred = test_clf.predict(X_test)
test_labels = np.unique(y_test)

print("Classification Report (Test Set)")
print(classification_report(
    y_test, y_pred,
    labels=test_labels,
    target_names=le.inverse_transform(test_labels),
    digits=3,
    zero_division=0
))
print("Accuracy:", accuracy_score(y_test, y_pred))
# 813
# Out:
# Classification Report (Test Set)
#                                                           precision    recall  f1-score   support
#
#                                abdominal aortic aneurysm      0.667     0.500     0.571         8
#                                         abdominal hernia      0.939     0.868     0.902        53
#                                          abscess of nose      0.905     0.633     0.745        30
#                                      abscess of the lung      0.000     0.000     0.000         1
#                                   abscess of the pharynx      0.818     0.818     0.818        33
#                                     acanthosis nigricans      0.000     0.000     0.000         2
#                                                acariasis      0.000     0.000     0.000         2
#                                                achalasia      1.000     0.200     0.333         5
#                                                     acne      0.656     0.656     0.656        61
#                                        actinic keratosis      0.831     0.728     0.776       162
#                                      acute bronchiolitis      0.912     0.942     0.927       241
#                                         acute bronchitis      0.750     0.790     0.770       243
#                                       acute bronchospasm      0.658     0.747     0.699       162
#                                           acute glaucoma      0.296     0.267     0.281        30
#                                      acute kidney injury      0.880     0.951     0.914       162
#                                       acute otitis media      0.592     0.869     0.705       107
#                                       acute pancreatitis      0.829     0.884     0.855       241
#               acute respiratory distress syndrome (ards)      0.810     0.783     0.797        60
#                                          acute sinusitis      0.772     0.753     0.762       166
#                                    acute stress reaction      0.831     0.919     0.872       160
#                      adhesive capsulitis of the shoulder      0.000     0.000     0.000         7
#                                      adjustment reaction      0.691     0.758     0.723        62
#                                          adrenal adenoma      0.000     0.000     0.000         2
#                                       dysthymic disorder      0.725     0.794     0.758        63
#                                          ear drum damage      0.917     0.872     0.894       164
#                                        ear wax impaction      0.779     0.830     0.804       106
#                                          eating disorder      1.000     0.983     0.992        60
#                                        ectopic pregnancy      0.641     0.714     0.676        35
#                                                ectropion      0.000     0.000     0.000         3
#                                                   eczema      0.805     0.752     0.778       242
#                                                emphysema      0.000     0.000     0.000         1
#                                                  empyema      0.000     0.000     0.000         1
#                                             encephalitis      0.000     0.000     0.000         5
#                                             endocarditis      0.000     0.000     0.000         7
#                                       endometrial cancer      0.000     0.000     0.000         5
#                                  endometrial hyperplasia      0.000     0.000     0.000         3
#                                            endometriosis      0.978     0.830     0.898        53
#                                          endophthalmitis      1.000     1.000     1.000         7
#                  envenomation from spider or animal bite      0.906     0.967     0.935        60
#                                               ependymoma      0.000     0.000     0.000         1
#                                             epididymitis      0.881     0.922     0.901        64
#                                                 epilepsy      0.846     1.000     0.917        11
#                                     erectile dysfunction      0.827     0.896     0.860        96
#                                      erythema multiforme      0.000     0.000     0.000         3
#                                        esophageal cancer      0.000     0.000     0.000         4
#                                              esophagitis      0.882     0.926     0.904       243
#                                         essential tremor      1.000     0.867     0.929        15
#               eustachian tube dysfunction (ear disorder)      0.895     0.944     0.919       162
#                           extrapyramidal effect of drugs      0.000     0.000     0.000         6
#                                   eye alignment disorder      0.934     0.983     0.958        58
#                                      factitious disorder      0.000     0.000     0.000         1
#                               female genitalia infection      1.000     0.938     0.968        16
#                      female infertility of unknown cause      0.000     0.000     0.000         3
#                                   fetal alcohol syndrome      0.000     0.000     0.000         1
#                                             fibroadenoma      0.000     0.000     0.000         8
#                               fibrocystic breast disease      0.000     0.000     0.000         1
#                                             fibromyalgia      0.726     0.683     0.704       101
#                                                flat feet      0.000     0.000     0.000         3
#                                                 floaters      0.000     0.000     0.000         3
#                                                      flu      0.843     0.875     0.858       104
#                                           fluid overload      0.833     0.735     0.781        34
#                                        folate deficiency      0.000     0.000     0.000         3
#                                             food allergy      0.800     0.842     0.821        57
#                                  foreign body in the ear      0.000     0.000     0.000         4
#                                  foreign body in the eye      0.364     0.387     0.375        31
#               foreign body in the gastrointestinal tract      0.667     0.667     0.667         9
#                               foreign body in the throat      1.000     0.786     0.880        14
#                               foreign body in the vagina      0.000     0.000     0.000         1
#                                    fracture of the ankle      0.200     0.143     0.167         7
#                                      fracture of the arm      0.883     0.872     0.877        78
#                             fracture of the facial bones      0.982     0.948     0.965        58
#                                   fracture of the finger      0.000     0.000     0.000         2
#                                     fracture of the foot      0.000     0.000     0.000         3
#                                     fracture of the hand      0.750     0.600     0.667        20
#                                      fracture of the jaw      0.500     0.429     0.462         7
#                                      fracture of the leg      0.847     0.943     0.893       106
#                                     fracture of the neck      0.000     0.000     0.000         5
#                                  fracture of the patella      0.000     0.000     0.000         6
#                                   fracture of the pelvis      0.833     0.882     0.857        17
#                                      fracture of the rib      0.949     0.949     0.949       158
#                                 fracture of the shoulder      1.000     0.941     0.970        17
#                                    fracture of the skull      0.000     0.000     0.000         3
#                                 fracture of the vertebra      1.000     0.935     0.967        31
#                                                frostbite      0.000     0.000     0.000         1
#                             fungal infection of the hair      0.863     0.753     0.804       243
#                             fungal infection of the skin      0.580     0.748     0.653       107
#                            galactorrhea of unknown cause      0.000     0.000     0.000         2
#                                                gallstone      0.702     0.827     0.759       162
#                                            ganglion cyst      0.946     0.991     0.968       106
#                                                gastritis      0.796     0.819     0.808       105
#                                     gastroduodenal ulcer      0.850     0.867     0.858       105
#                   gastroesophageal reflux disease (gerd)      0.803     0.883     0.841        60
#                              gastrointestinal hemorrhage      0.927     0.885     0.905       243
#                                            gastroparesis      1.000     0.333     0.500        15
#                                           genital herpes      0.933     0.875     0.903        16
#                                     gestational diabetes      0.000     0.000     0.000         3
#                                                 glaucoma      0.537     0.571     0.554        63
#                                glucocorticoid deficiency      0.000     0.000     0.000         1
#                                                   goiter      0.000     0.000     0.000         4
#                                                gonorrhea      1.000     0.750     0.857         8
#                                                     gout      0.922     0.934     0.928       242
#                                           graves disease      0.889     0.889     0.889        18
#                                  guillain barre syndrome      0.000     0.000     0.000         3
#                                              gum disease      0.793     0.739     0.765       161
#                                             gynecomastia      0.706     0.923     0.800        13
#                                               hammer toe      0.000     0.000     0.000         2
#                                     head and neck cancer      1.000     0.848     0.918        33
#                                              head injury      0.889     0.923     0.906        26
#                           headache after lumbar puncture      1.000     0.467     0.636        15
#                                             heart attack      0.934     0.963     0.948       162
#                                              heart block      0.830     0.821     0.825        95
#                                            heart failure      0.901     0.951     0.925       163
#                                          heat exhaustion      0.708     0.607     0.654        28
#                                               hemangioma      0.743     0.757     0.750       103
#                                             hemarthrosis      0.000     0.000     0.000         1
#                                                 hematoma      0.000     0.000     0.000         3
#                                               hemiplegia      0.921     0.935     0.928        62
#                                          hemochromatosis      0.000     0.000     0.000         1
#                                         hemolytic anemia      0.000     0.000     0.000         2
#                                               hemophilia      0.000     0.000     0.000         2
#                                              hemorrhoids      0.890     0.939     0.914       164
#                                   hepatic encephalopathy      1.000     0.500     0.667         4
#                                 hepatitis due to a toxin      1.000     0.848     0.918        33
#                                           herniated disk      0.665     0.729     0.695       166
#                                               herpangina      0.889     0.933     0.911        60
#                                            hiatal hernia      0.923     0.951     0.937       163
#                                 hidradenitis suppurativa      1.000     0.714     0.833         7
#                                     hirschsprung disease      0.000     0.000     0.000         1
#                                                hirsutism      0.000     0.000     0.000         1
#                                         hormone disorder      0.000     0.000     0.000         2
#                                                      hpv      0.000     0.000     0.000         1
#                                        hydatidiform mole      1.000     0.500     0.667         4
#                                hydrocele of the testicle      0.759     0.786     0.772        28
#                                            hydrocephalus      0.667     0.714     0.690        14
#                                           hydronephrosis      0.667     0.606     0.635        33
#                                            hypercalcemia      0.000     0.000     0.000         1
#                                     hypercholesterolemia      0.000     0.000     0.000         2
#                                   hyperemesis gravidarum      0.890     0.939     0.913       163
#                                            hyperhidrosis      0.000     0.000     0.000         2
#                                             hyperkalemia      0.913     0.931     0.922       101
#                                            hypernatremia      0.000     0.000     0.000         4
#                                                hyperopia      0.667     0.571     0.615         7
#                          hyperosmotic hyperketotic state      0.000     0.000     0.000         1
#                                hypertension of pregnancy      1.000     0.857     0.923         7
#                               hypertensive heart disease      0.945     0.963     0.954       161
#           hypertrophic obstructive cardiomyopathy (hocm)      0.000     0.000     0.000         1
#                                             hypocalcemia      0.000     0.000     0.000         3
#                                             hypoglycemia      0.956     0.992     0.974       243
#                                              hypokalemia      0.846     0.857     0.852        77
#                                             hyponatremia      0.639     0.855     0.731        62
#                                              hypothermia      0.000     0.000     0.000         1
#                                           hypothyroidism      1.000     0.571     0.727         7
#                                              hypovolemia      0.893     0.877     0.885        57
#                       idiopathic absence of menstruation      0.855     0.914     0.883        58
#                        idiopathic excessive menstruation      0.842     0.837     0.840       166
#                       idiopathic infrequent menstruation      0.000     0.000     0.000         2
#                     idiopathic irregular menstrual cycle      0.747     0.853     0.797       163
#                         idiopathic nonmenstrual bleeding      0.333     0.200     0.250         5
#                          idiopathic painful menstruation      0.809     0.870     0.838       161
#                                                    ileus      0.731     0.845     0.784        58
#                                                 impetigo      0.950     0.905     0.927       105
#                                 impulse control disorder      0.469     0.455     0.462        33
#                                              indigestion      0.846     0.759     0.800        58
#                                         induced abortion      0.769     0.645     0.702        31
#                                  infection of open wound      0.000     0.000     0.000         1
#                               infectious gastroenteritis      0.639     0.720     0.677       243
#                                         ingrown toe nail      0.966     0.904     0.934        94
#                                          inguinal hernia      0.854     0.933     0.892        75
#                                      injury of the ankle      0.793     0.885     0.836        26
#                                 injury to internal organ      1.000     0.429     0.600         7
#                                    injury to the abdomen      0.000     0.000     0.000         3
#                                        injury to the arm      0.930     0.930     0.930       242
#                                       injury to the face      0.933     1.000     0.966        56
#                                     injury to the finger      0.000     0.000     0.000         1
#                                       injury to the hand      0.625     0.714     0.667        14
#                                        injury to the hip      0.000     0.000     0.000         2
#                                       injury to the knee      0.000     0.000     0.000         4
#                                        injury to the leg      0.913     0.954     0.933       241
#                                   injury to the shoulder      0.982     0.889     0.933        63
#                                injury to the spinal cord      0.000     0.000     0.000         2
#                                      injury to the trunk      0.970     0.988     0.978       161
#                                              insect bite      0.823     0.903     0.861       103
#                                interstitial lung disease      0.718     0.910     0.803        67
#                              intertrigo (skin condition)      0.000     0.000     0.000         8
#                                        intestinal cancer      0.000     0.000     0.000         3
#                                       intestinal disease      0.658     0.676     0.667        37
#                                 intestinal malabsorption      0.923     0.923     0.923        13
#                                   intestinal obstruction      0.962     0.879     0.919        58
#                                 intracerebral hemorrhage      0.821     0.935     0.874        93
#                                     intracranial abscess      0.000     0.000     0.000         1
#                                  intracranial hemorrhage      0.757     0.933     0.836        30
#                                          intussusception      0.000     0.000     0.000         1
#                                            iridocyclitis      0.773     0.850     0.810        60
#                                   iron deficiency anemia      0.972     0.991     0.981       106
#                                 irritable bowel syndrome      0.938     0.923     0.930        65
#                                    ischemia of the bowel      0.444     0.211     0.286        19
#                                   ischemic heart disease      0.853     0.950     0.899       159
#                                 itching of unknown cause      0.952     0.968     0.960        62
#                                             jaw disorder      0.939     0.912     0.925        34
#                                           joint effusion      0.943     0.862     0.901        58
#                            juvenile rheumatoid arthritis      0.333     0.333     0.333         3
#                                            kidney cancer      0.000     0.000     0.000         5
#          kidney disease due to longstanding hypertension      0.000     0.000     0.000         1
#                                           kidney failure      0.969     0.969     0.969        32
#                                             kidney stone      0.568     0.608     0.587       158
#                           knee ligament or meniscus tear      1.000     0.692     0.818        13
#                                            labyrinthitis      0.969     0.921     0.944       101
#                                      lactose intolerance      1.000     0.750     0.857         8
#                                               laryngitis      0.951     0.933     0.942       104
#                     lateral epicondylitis (tennis elbow)      0.806     0.714     0.758        35
#                                                 leukemia      0.000     0.000     0.000         1
#                                       lewy body dementia      0.000     0.000     0.000         5
#                                                     lice      0.000     0.000     0.000         3
#                                           lichen simplex      1.000     0.250     0.400         4
#                                                   lipoma      0.897     0.932     0.914       103
#                                             liver cancer      0.000     0.000     0.000         4
#                                            liver disease      0.979     0.963     0.971       242
#                                                  lumbago      1.000     0.786     0.880        14
#                                              lung cancer      0.200     0.222     0.211         9
#                                           lung contusion      0.000     0.000     0.000         1
#                                             lyme disease      0.810     1.000     0.895        17
#                                            lymphadenitis      0.932     0.948     0.940        58
#                                               lymphedema      0.932     0.873     0.902        63
#                                 lymphogranuloma venereum      0.000     0.000     0.000         1
#                                                 lymphoma      0.714     0.625     0.667         8
#                                     macular degeneration      0.750     0.663     0.704       163
#                                     magnesium deficiency      0.000     0.000     0.000         1
#                                                  malaria      0.000     0.000     0.000         1
#                                 male genitalia infection      0.200     0.125     0.154         8
#                                   malignant hypertension      0.867     0.765     0.812        17
#                                          marijuana abuse      0.826     0.707     0.762       242
#                                               mastectomy      0.000     0.000     0.000         1
#                                              mastoiditis      0.500     0.333     0.400         9
#                                                 melanoma      1.000     0.903     0.949        31
#                                          meniere disease      0.966     0.875     0.918        32
#                                               meningioma      0.000     0.000     0.000         1
#                                               meningitis      0.839     0.812     0.825        32
#                                                menopause      0.800     0.667     0.727         6
#                                       metabolic disorder      0.000     0.000     0.000         2
#                                        metastatic cancer      0.000     0.000     0.000         4
#                                                 migraine      0.927     0.927     0.927        41
#                                          missed abortion      0.854     0.673     0.753        52
#                                     mitral valve disease      0.842     0.787     0.814        61
#                                            mittelschmerz      0.333     0.333     0.333         6
#                                    molluscum contagiosum      0.620     0.698     0.657        63
#                                             mononeuritis      0.786     0.868     0.825       106
#                                            mononucleosis      0.893     0.781     0.833        32
#                                                mucositis      0.900     0.871     0.885        31
#                                         multiple myeloma      0.000     0.000     0.000         4
#                                       multiple sclerosis      0.862     0.909     0.885       165
#                                                    mumps      0.000     0.000     0.000         2
#                                             muscle spasm      0.767     0.885     0.821       104
#                                       muscular dystrophy      0.000     0.000     0.000         2
#                                        myasthenia gravis      1.000     0.800     0.889        10
#                                                myoclonus      0.000     0.000     0.000         1
#                                                   myopia      0.821     0.793     0.807        58
#                                                 myositis      1.000     0.375     0.545         8
#                                               narcolepsy      0.909     0.625     0.741        16
#                                              nasal polyp      0.962     0.758     0.847        33
#                                        neonatal jaundice      0.000     0.000     0.000         3
#                      nerve impingement near the shoulder      0.848     0.875     0.862        32
#                                                neuralgia      0.507     0.660     0.574       106
#                                        neurofibromatosis      0.000     0.000     0.000         2
#                                  neuropathy due to drugs      0.000     0.000     0.000         2
#                                                 neurosis      0.976     0.775     0.864       160
#                        nonalcoholic liver disease (nash)      0.000     0.000     0.000         4
#                            noninfectious gastroenteritis      0.662     0.643     0.653       241
#                            normal pressure hydrocephalus      0.000     0.000     0.000         1
#                                            nose disorder      0.853     0.807     0.829       244
#                      obsessive compulsive disorder (ocd)      0.981     0.912     0.945        57
#                            obstructive sleep apnea (osa)      0.948     1.000     0.974       239
#                                            onychomycosis      0.803     0.919     0.857        62
#                        open wound from surgical incision      0.000     0.000     0.000         1
#                                    open wound of the arm      0.000     0.000     0.000         1
#                                   open wound of the back      0.000     0.000     0.000         1
#                                    open wound of the ear      0.000     0.000     0.000         3
#                                    open wound of the eye      0.000     0.000     0.000         3
#                                 open wound of the finger      0.000     0.000     0.000         1
#                                   open wound of the foot      0.000     0.000     0.000         5
#                                   open wound of the hand      0.000     0.000     0.000         1
#                                    open wound of the lip      0.000     0.000     0.000         2
#                                  open wound of the mouth      0.000     0.000     0.000         6
#                                   open wound of the neck      0.000     0.000     0.000         3
#                                   open wound of the nose      0.000     0.000     0.000         2
#                                    oppositional disorder      0.987     0.974     0.981        78
#                                           optic neuritis      0.000     0.000     0.000         1
#                                      oral mucosal lesion      0.874     0.918     0.896        98
#                            oral thrush (yeast infection)      0.912     0.972     0.941       106
#                                       orbital cellulitis      1.000     0.688     0.815        16
#                                  orthostatic hypotension      0.905     0.655     0.760        29
#                                           osteoarthritis      0.888     0.943     0.915       159
#                                           osteochondroma      0.933     0.875     0.903        16
#                                          osteochondrosis      0.857     0.750     0.800         8
#                                            osteomyelitis      0.929     0.867     0.897        15
#                                             osteoporosis      0.982     1.000     0.991        54
#                           otitis externa (swimmer's ear)      0.954     0.895     0.924       162
#                                             otitis media      0.832     0.708     0.765       161
#                                             otosclerosis      0.000     0.000     0.000         1
#                                           ovarian cancer      0.000     0.000     0.000         2
#                                             ovarian cyst      0.698     0.746     0.721        59
#                                          ovarian torsion      0.714     0.714     0.714         7
#                                    overflow incontinence      0.875     0.875     0.875        16
#                                  pain after an operation      0.838     0.901     0.868       161
#                         pain disorder affecting the neck      0.980     0.943     0.962        53
#                                        pancreatic cancer      0.875     0.824     0.848        17
#                                             panic attack      1.000     0.538     0.700        13
#                                           panic disorder      0.814     0.920     0.864       162
#                                        parasitic disease      1.000     0.600     0.750         5
#                                      parathyroid adenoma      0.000     0.000     0.000         2
#                                        parkinson disease      0.932     0.873     0.902        63
#                                               paronychia      0.931     0.982     0.956        55
#                  paroxysmal supraventricular tachycardia      0.804     0.712     0.755        52
#                       paroxysmal ventricular tachycardia      0.725     0.767     0.745       103
#                              pelvic inflammatory disease      0.778     0.870     0.821       161
#                                    pelvic organ prolapse      0.897     0.897     0.897        58
#                                             pericarditis      0.667     0.750     0.706         8
# ...
#                                   primary kidney disease      0.000     0.000     0.000         3
#                                 problem during pregnancy      0.841     0.902     0.871       164
#                                          prostate cancer      0.875     0.667     0.757        21
#                                              prostatitis      0.850     0.892     0.871       102
#                                       protein deficiency      0.000     0.000     0.000         3
#                                 pseudohypoparathyroidism      0.000     0.000     0.000         1
#                                      pseudotumor cerebri      0.000     0.000     0.000         3
#                                                psoriasis      0.667     0.752     0.707       165
#                                    psychosexual disorder      0.773     1.000     0.872        17
#                                       psychotic disorder      0.490     0.456     0.472       160
#                                                pterygium      0.889     0.533     0.667        15
#                                     pulmonary congestion      0.942     0.803     0.867        61
#                                       pulmonary embolism      0.961     0.924     0.942       158
#                                   pulmonary eosinophilia      0.789     0.882     0.833        17
#                                       pulmonary fibrosis      0.727     0.615     0.667        13
#                                   pulmonary hypertension      1.000     0.930     0.964        57
#                                           pyelonephritis      0.605     0.609     0.607       161
#                                         pyloric stenosis      0.000     0.000     0.000         1
#                                  pyogenic skin infection      0.915     0.904     0.910       167
#                                          raynaud disease      0.000     0.000     0.000         1
#                                          rectal disorder      0.890     0.901     0.896       162
#                                    restless leg syndrome      0.867     0.839     0.852        31
#                                       retinal detachment      0.275     0.452     0.341        31
#                   retinopathy due to high blood pressure      0.250     0.222     0.235         9
#                                           rhabdomyolysis      0.000     0.000     0.000         2
#                                     rheumatoid arthritis      0.934     0.952     0.943       104
#                                                  rosacea      0.886     0.750     0.812       104
#                                      rotator cuff injury      0.400     0.250     0.308         8
#                                  salivary gland disorder      0.000     0.000     0.000         2
#                                              sarcoidosis      1.000     1.000     1.000        32
#                                                  scabies      1.000     0.882     0.938        17
#                                                     scar      0.571     0.222     0.320        18
#                                            scarlet fever      0.000     0.000     0.000         7
#                                            schizophrenia      0.625     0.556     0.588       162
#                                                 sciatica      0.843     0.875     0.858       104
#                                                scleritis      0.000     0.000     0.000         3
#                                              scleroderma      0.833     0.882     0.857        34
#                                                scoliosis      0.867     0.765     0.812        17
#                           seasonal allergies (hay fever)      0.950     0.926     0.938       163
#                                           sebaceous cyst      0.930     0.896     0.913       164
#                                    seborrheic dermatitis      0.898     0.769     0.828       160
#                                     seborrheic keratosis      0.360     0.372     0.366       156
#                               sensorineural hearing loss      0.836     0.868     0.852       106
#                                                   sepsis      0.906     0.933     0.919       165
#                                         septic arthritis      0.000     0.000     0.000         4
#                                 shingles (herpes zoster)      1.000     0.980     0.990        49
#                                            sialoadenitis      0.953     0.953     0.953        64
#                                      sick sinus syndrome      0.286     0.333     0.308        24
#                                       sickle cell anemia      0.931     1.000     0.964        27
#                                       sickle cell crisis      0.905     0.883     0.894       162
#                                        sinus bradycardia      0.742     0.865     0.799       163
#                                         sjogren syndrome      0.571     0.667     0.615         6
#                                              skin cancer      0.584     0.567     0.576       104
#                                            toxoplasmosis      0.000     0.000     0.000         1
#                                               tracheitis      0.833     0.714     0.769        14
#                                transient ischemic attack      0.861     0.886     0.873       105
#                                               trichiasis      0.000     0.000     0.000         2
#                                    trichomonas infection      0.765     0.812     0.788        32
#                                     trigeminal neuralgia      0.722     0.812     0.765        16
#                         trigger finger (finger disorder)      1.000     0.750     0.857         8
#                                             tuberculosis      0.000     0.000     0.000         2
#                                       tuberous sclerosis      0.000     0.000     0.000         1
#                                       ulcerative colitis      0.956     0.796     0.869        54
#                                        urethral disorder      0.773     0.567     0.654        30
#                                       urethral stricture      0.774     0.774     0.774        31
#                                          urethral valves      0.000     0.000     0.000         3
#                                               urethritis      0.791     0.883     0.835        60
#                                        urge incontinence      0.891     0.831     0.860        59
#                                  urinary tract infection      0.682     0.804     0.738       163
#                                urinary tract obstruction      0.832     0.840     0.836       106
#                                            uterine atony      0.919     0.872     0.895        39
#                                         uterine fibroids      0.810     0.586     0.680        58
#                                                  uveitis      0.000     0.000     0.000         1
#                                             vaginal cyst      0.752     0.823     0.786       243
#                                  vaginal yeast infection      0.822     0.838     0.830        99
#                                               vaginismus      1.000     0.333     0.500         6
#                                                vaginitis      0.790     0.896     0.840       164
#                                             valley fever      0.000     0.000     0.000         1
#                              varicocele of the testicles      0.927     0.962     0.944       106
#                                           varicose veins      0.938     0.750     0.833        20
#                                               vasculitis      0.912     0.939     0.925        33
#                                     venous insufficiency      0.850     1.000     0.919        34
#                            vertebrobasilar insufficiency      0.000     0.000     0.000         1
#                                    vesicoureteral reflux      0.000     0.000     0.000         1
#                                           viral exanthem      0.862     0.827     0.844        98
#                                          viral hepatitis      0.000     0.000     0.000         4
#                                              viral warts      0.623     0.655     0.639        58
#                                   vitamin b12 deficiency      0.500     0.200     0.286         5
#                                     vitamin d deficiency      0.000     0.000     0.000         1
#                                    vitreous degeneration      0.283     0.500     0.362        34
#                                      vitreous hemorrhage      0.000     0.000     0.000         5
#                                         vocal cord polyp      0.000     0.000     0.000         4
#                                                 volvulus      0.000     0.000     0.000         1
#                                            vulvar cancer      0.000     0.000     0.000         1
#                                          vulvar disorder      1.000     0.333     0.500         9
#                                               vulvodynia      0.909     0.857     0.882       244
#                              wernicke korsakoff syndrome      0.000     0.000     0.000         1
#                                 white blood cell disease      0.906     0.762     0.828        63
#                                           whooping cough      0.000     0.000     0.000         3
#                                           wilson disease      0.000     0.000     0.000         1
#                                          yeast infection      0.925     0.845     0.883        58
#                                      zenker diverticulum      0.000     0.000     0.000         1
#
#                                                 accuracy                          0.813     37921
#                                                macro avg      0.570     0.532     0.542     37921
#                                             weighted avg      0.813     0.813     0.810     37921
#
# Accuracy: 0.8132169510297724

# %%
print("\nConfusion Matrix")
cm = confusion_matrix(y_test, y_pred, labels=test_labels)
cm_df = pd.DataFrame(
    cm,
    index=le.inverse_transform(test_labels),
    columns=le.inverse_transform(test_labels)
)
cm_df.to_csv(OUT_CSV, index=True, encoding="utf-8-sig")
# Out:
# Confusion Matrix
